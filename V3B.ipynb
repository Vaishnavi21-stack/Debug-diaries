# %%
region='south india'
result= region.title()
print(result)
# Out:
# South India

# %%
x = 10
y = "20"

print(str(x) + y)
# Out:
# 1020

# %%
ages = [22, 35, 45, 28, 35, 40]

result = sorted(set(ages))

print(result)
# Out:
# [22, 28, 35, 40, 45]

# %%
sales = 1200

result = "High" if sales > 1000 else "Low"
print(result)
# Out:
# High
